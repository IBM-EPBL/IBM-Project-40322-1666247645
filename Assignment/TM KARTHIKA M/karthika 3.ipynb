# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.datasets import mnist

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255,horizontal_flip=True,vertical_flip=True,zoom_range=0.2)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Convolution2D,MaxPooling2D,Flatten,Dense

# %%
x_train=train_datagen.flow_from_directory(r"/content/drive/My Drive/flowers",target_size=(64,64),class_mode="categorical",batch_size=24)
# Out:
# Found 4317 images belonging to 5 classes.

# %%
x_train=train_datagen.flow_from_directory(r"/content/drive/My Drive/flowers",target_size=(64,64),class_mode="categorical",batch_size=24)
# Out:
# Found 4317 images belonging to 5 classes.

# %% [markdown]
# CREATE MODEL

# %%
model=Sequential()

# %% [markdown]
# Add Layers (Convolution,MaxPooling,Flatten,Dense-(Hidden Layers),Output)

# %%
model.add(Convolution2D(32,(3,3),activation="relu",input_shape=(64,64,3)))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Flatten())

# %%
model.add(Dense(300,activation='relu'))

# %%
model.add(Dense(300,activation='relu'))

# %%
model.add(Dense(5,activation="softmax"))

# %% [markdown]
# Compile The Model

# %%
model.compile(loss="categorical_crossentropy",metrics=["accuracy"],optimizer='adam')

# %%
len(x_train)
# Out:
# 180

# %% [markdown]
# Fit the model

# %%
model.fit(x_train,epochs=5,validation_data=x_test,steps_per_epoch=len(x_train),validation_steps=len(x_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-18a2e439f7d1> in <module>
# ----> 1 model.fit(x_train,epochs=5,validation_data=x_test,steps_per_epoch=len(x_train),validation_steps=len(x_test))
#
# NameError: name 'x_test' is not defined

# %% [markdown]
# SAVE THE MODEL

# %%
model.save("flower1.h5")

# %% [markdown]
# TEST THE MODEL

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image 
import numpy as np

# %%
img=image.load_img("/content/drive/My Drive/flowers/rose/99383371_37a5ac12a3_n.jpg",target_size=(64,64))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F0A53B8AD90>

# %%
x=image.img_to_array(img)

# %%
x
# Out:
# array([[[ 80.,  77.,  58.],
#         [110., 109.,  88.],
#         [184., 161., 109.],
#         ...,
#         [188., 185., 168.],
#         [192., 193., 179.],
#         [193., 194., 180.]],
#
#        [[ 82.,  84.,  63.],
#         [109., 107.,  82.],
#         [144., 127.,  83.],
#         ...,
#         [183., 182., 162.],
#         [188., 187., 169.],
#         [187., 186., 168.]],
#
#        [[ 93.,  95.,  74.],
#         [116., 114.,  89.],
#         [ 83.,  82.,  64.],
#         ...,
#         [178., 175., 156.],
#         [182., 181., 163.],
#         [181., 180., 162.]],
#
#        ...,
#
#        [[ 20.,  36.,  25.],
#         [ 65.,  65.,  41.],
#         [ 97.,  99.,  75.],
#         ...,
#         [168., 163., 141.],
#         [173., 170., 151.],
#         [167., 164., 145.]],
#
#        [[ 45.,  57.,  47.],
#         [ 39.,  51.,  47.],
#         [ 62.,  70.,  55.],
#         ...,
#         [175., 173., 150.],
#         [172., 171., 150.],
# ...

# %%
x.ndim
# Out:
# 3

# %%
x=np.expand_dims(x,axis=0)

# %%
x.ndim
# Out:
# 4

# %%
pred=model.predict(x)
# Out:
# 1/1 [==============================] - 0s 320ms/step

# %%
pred
# Out:
# array([[4.8171053e-21, 9.9999833e-01, 5.3606713e-18, 1.6286556e-06,
#         1.1227925e-10]], dtype=float32)

# %%
labels=["daisy","dandelion","rose","sunflower","tulip"]

# %%
np.argmax(pred)
# Out:
# 1

# %%
labels[2]
# Out:
# 'rose'

# %%
labels[np.argmax(pred)]
# Out:
# 'dandelion'
